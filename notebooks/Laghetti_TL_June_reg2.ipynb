# %% [markdown]
# # Notebook for the Alento (site nb2) data processing
#
# - 🔨 Data acquisition: Nico, Ben
# - Notebook Author: B. Mary
#
# ### Steps to reproduce
# - import all libraries
# - import raw merged data
# - create resipy project 3d
# - import electrode geometry
# - create thetra mesh
# - invert
# - show results

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Dec  6 09:22:55 2021

@author: ben
"""
# import resipy and other useful libraries
# -----------------------------------------------------------------------------
#get_ipython().run_line_magic('matplotlib', 'inline')
import warnings
warnings.filterwarnings('ignore')
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pyvista as pv

import ipywidgets

# %%
#!pip install resipy==3.3.2

# %%
correct_topo = 0
per_rec = 10 #10

# %%
sys.path.append((os.path.relpath('../src'))) # add here the relative path of the API folder
from resipy import Project
# Out:
# API path =  /home/ben/miniconda3/lib/python3.9/site-packages/resipy
# ResIPy version =  3.3.2
# cR2.exe found and up to date.
# R3t.exe found and up to date.
# cR3t.exe found and up to date.

# %%
regMode = 2
dir_simu = '../INV/timeLapse/TL_June_Laghetti_' + 'regMode' + str(regMode)
k = Project(dirname=dir_simu, typ='R3t')
k.setTitle('Laghetti')
# Out:
# Working directory is: /home/ben/Documents/GitHub/BenjMy/Salorno_river/INV/timeLapse/TL_June_Laghetti_regMode2
# clearing dirname

# %% [markdown]
# # Set reciprocal filter to 10%

# %%
print(os.getcwd())

import pandas

filenames = [
            '../rawData/Laghetti/June/file120data0_20giugno2022.dat',
            '../rawData/Laghetti/June/file120data1_22giugno2022.dat',
            '../rawData/Laghetti/June/file120data2_24giugno2022.dat',
            '../rawData/Laghetti/June/file120data3_27giugno2022.dat',
            ]
# Out:
# /home/ben/Documents/GitHub/BenjMy/Salorno_river/notebooks

# %%
column_names = ['Spa.1','Spa.2','Spa.3','Spa.4','Vp','In']
idx = [0,1,2,3,8,9]
filenames_csv = []
for f in filenames:
    numpyfile = np.loadtxt(f, skiprows=1)
    df=pd.DataFrame(numpyfile[:,idx],columns=column_names)
    df['dev']=np.zeros(len(df['Spa.1']))
    df = df.astype({"Spa.1": int}) 
    df = df.astype({"Spa.2": int}) 
    df = df.astype({"Spa.3": int}) 
    df = df.astype({"Spa.4": int}) 
    filenames_csv.append(f + '.csv')
    df.to_csv(f + '.csv',sep=',',index=False)

# %%
# create survey
# -----------------------------------------------------------------------------
print(os.getcwd())
k.createTimeLapseSurvey(filenames_csv,
                         ftype='Syscal')
k.filterRecip(index=-1, percent=per_rec)
# Out:
# /home/ben/Documents/GitHub/BenjMy/Salorno_river/notebooks
# 4/4 imported
# 11229 measurements with greater than 10.0% reciprocal error removed!
# 10323 measurements with greater than 10.0% reciprocal error removed!
# 10597 measurements with greater than 10.0% reciprocal error removed!
# 10374 measurements with greater than 10.0% reciprocal error removed!
# 42523

# %% [markdown]
# # Create boreholes geometry
#
# ### raw file: coordinatepozzilaghetti.txt

# %%
# create boreholes geometry
# -----------------------------------------------------------------------------
nb_elecs_bor = 24
elecs_spacing = 1
offset = 1
asc_bor = np.arange(-nb_elecs_bor*elecs_spacing-offset,0-offset)
des_bor = np.flip(asc_bor)
elecs_z = np.hstack([asc_bor,des_bor,des_bor,des_bor,des_bor])

elecs = []
label = []

# lat/long of the electrodes
# -----------------------------------------------------------------------------
pozzi_coords = pd.read_csv('../survey/coordinatepozzilaghetti.txt', header='infer')

# lat/long to absolute positions
# -----------------------------------------------------------------------------
pozzi_coords['x'] = pozzi_coords['x'] - min(pozzi_coords['x'])
pozzi_coords['y'] = pozzi_coords['y'] - min(pozzi_coords['y'])
pozzi_coords['z'] = pozzi_coords['z'] - max(pozzi_coords['z'])


i=1
for index, row in pozzi_coords.iterrows():
    for ne in range(len(asc_bor)):
        elecs.append([row[1],row[2],row[3]])
        # print([str(1),str((ne+1)*(index+1))])
        # label.append(' '.join([str(index+1),str(ne+1)]))
        # label.append(' '.join([str(1),str(i)]))
        label.append(' '.join([str(i)]))
        i +=1

# correct for altitude
# -----------------------------------------------------------------------------
for ze in enumerate(elecs_z):
    # print(ze)
    if correct_topo == 1:
        elecs[ze[0]][2] +=  ze[1]
    else:
        elecs[ze[0]][2] =  ze[1]

elecs = np.vstack(elecs)

if correct_topo == 1:
    max_elecs = pozzi_coords['z'] - 2
else:
    max_elecs= max(elecs[:,2])

# buried flag for upper surface electrode is False!
# -----------------------------------------------------------------------------
buried = []
for e in elecs:
    if (round(e[2],4) == round(max_elecs, 4)).any():
        buried.append(False)
    else:
        buried.append(True)
            
# plot electrode positions
# -----------------------------------------------------------------------------
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(elecs[:,0], elecs[:,1], elecs[:,2], marker='o')

ax.set_xlabel('Lat (m)')
ax.set_ylabel('Long (m)')
ax.set_zlabel('Altitude z (m)')

plt.show()

# electrode positions to dataframe
# -----------------------------------------------------------------------------
elecs_df = pd.DataFrame(elecs,columns=['x', 'y', 'z'])
elecs_df['label'] = label
elecs_df['buried'] = buried

elecs_df.to_csv('./elecs120data.csv', index=False)
elecs_df.head()
# Out:
#      x       y     z label  buried
# 0  0.0  9.8939 -25.0     1    True
# 1  0.0  9.8939 -24.0     2    True
# 2  0.0  9.8939 -23.0     3    True
# 3  0.0  9.8939 -22.0     4    True
# 4  0.0  9.8939 -21.0     5    True

# %%
k.setElec(elecs_df)
#k.createMesh(refine=0)
k.createMesh(refine=0,cl_factor=5,cl=1) #,fmd=1

k.showMesh()
             # cl_factor=8.00, 
             # cln_factor=100.00,
# Out:
# Creating tetrahedral mesh...done (53740 elements)
# /home/ben/miniconda3/lib/python3.9/site-packages/vtkmodules/util/numpy_support.py:74: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   _vtk_np = {vtkConstants.VTK_BIT:numpy.bool,
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F65E0972A00>

# %% [markdown]
# # Inversion

# %%
# inversion
# -----------------------------------------------------------------------------
k.param['num_xy_poly'] = 0
k.param['z_min'] = -np.inf
k.param['z_max'] = np.inf

# k.param['z_min'] = max(elecs_df['z'])
# k.param['z_max'] = min(elecs_df['z'])
k.param['data_type'] = 1 # using log of resistitivy
k.err = False # if we want to use the error from the error models fitted before
k.param['a_wgt'] = 0.01
k.param['b_wgt'] = per_rec/100 #0.05
k.param['reg_mode'] = regMode
k.invert(parallel=False) # this will do the inversion
# k.saveData(MainPath)
# Out:
# Writing .in file and protocol.dat... Matching quadrupoles between surveys for difference inversion...5454 in common...done in 0.22006s
# done
# ------------ INVERTING REFERENCE SURVEY ---------------
#
#
#  >> R 3 t     E R T    M o d e l    v 2.31 <<
#
#  >> Date: 01-07-2022
#  >> Laghetti
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> A d v a n c e d   M e s h   I n p u t <<
#  >> T e t r a h e d r a l   E l e m e n t   M e s h <<
#
#  >> Reading mesh file
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading resistivity model from res0.dat
#
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#
#  >> Memory estimates:
#     For   1000 measurements the memory needed is:          0.449 Gb
#     For   2000 measurements the memory needed is:          0.879 Gb
#     For   5000 measurements the memory needed is:          2.169 Gb
#     For  10000 measurements the memory needed is:          4.319 Gb
#
#  >> Forming roughness matrix
#
#  >> Number of measurements read: 4344
#
#  >> Total Memory required is:          1.887 Gb
#
#
#  Processing frame   1 - output to file f001.dat
#
#    Iteration   1
#      Initial RMS Misfit:         6.45      Number of data ignored:   259
#      Alpha:        8138.692   RMS Misfit:        5.83  Roughness:        0.933
#      Alpha:        3777.646   RMS Misfit:        5.79  Roughness:        1.157
#      Alpha:        1753.428   RMS Misfit:        5.41  Roughness:        6.139
#      Alpha:         813.869   RMS Misfit:        5.08  Roughness:       14.540
#      Alpha:         377.765   RMS Misfit:        4.63  Roughness:       36.984
#      Alpha:         175.343   RMS Misfit:        4.24  Roughness:       73.963
#      Alpha:          81.387   RMS Misfit:        3.96  Roughness:      135.387
#      Alpha:          37.776   RMS Misfit:        3.79  Roughness:      230.086
#      Alpha:          17.534   RMS Misfit:        3.80  Roughness:      383.464
#      Step length set to      1.000
#      Final RMS Misfit:        3.79
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         2.23      Number of data ignored:   249
#      Alpha:          23.734   RMS Misfit:        1.82  Roughness:      221.321
#      Alpha:          11.017   RMS Misfit:        1.66  Roughness:      328.622
#      Alpha:           5.113   RMS Misfit:        1.60  Roughness:      403.966
#      Alpha:           2.373   RMS Misfit:        1.54  Roughness:      596.767
#      Alpha:           1.102   RMS Misfit:        1.58  Roughness:      880.448
#      Step length set to      1.000
#      Final RMS Misfit:        1.54
#      Attempted to update data weights and caused overshoot
#      treating as converged
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#  End of data:  Terminating
#
#
#  >> Program ended normally
#
# ----------------- Computing d-d0+f(m0) ---------------
# 0108:fixme:ver:GetCurrentPackageId (000000000011EB10 0000000000000000): stub
# Writing .in file and mesh.dat... done
# Writing protocol.dat... done
# Running forward model...
#
#  >> R 3 t     E R T    M o d e l    v 2.31 <<
#
#  >> Date: 01-07-2022
#  >> Laghetti
#  >> F o r w a r d   S o l u t i o n   S e l e c t e d <<
#  >> A d v a n c e d   M e s h   I n p u t <<
#  >> T e t r a h e d r a l   E l e m e n t   M e s h <<
#
#  >> Reading mesh file
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading resistivity model from resistivity.dat
#
#  >> Memory estimates:
#     For   1000 measurements the memory needed is:          0.013 Gb
#     For   2000 measurements the memory needed is:          0.013 Gb
#     For   5000 measurements the memory needed is:          0.013 Gb
#     For  10000 measurements the memory needed is:          0.013 Gb
#
#  >> Number of measurements read: 7990
#
#  >> Total Memory required is:          0.013 Gb
#
#
#  >> Program ended normally
# 012c:fixme:ver:GetCurrentPackageId (000000000011EB10 0000000000000000): stub
# 7292/7990 reciprocal measurements found.
# 0 measurements error > 20 %
# Forward modelling done.Matching quadrupoles between surveys for difference inversion...5454 in common...done in 0.33053s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 14>()
#      12 k.param['b_wgt'] = per_rec/100 #0.05
#      13 k.param['reg_mode'] = regMode
# ---> 14 k.invert(parallel=False)
#
# File ~/miniconda3/lib/python3.9/site-packages/resipy/Project.py:3672, in Project.invert(self, param, iplot, dump, modErr, parallel, iMoveElec, ncores, rmDirTree, modelDOI)
#    3670         self.sequence = None
#    3671         self.surveys = surveysBackup
# -> 3672         self.write2protocol(errTot=errTot, fm0=fm0) # rewrite them with d-d0+f(m0)
#    3673 elif self.iTimeLapse == True and self.referenceMdl==True:
#    3674     print('Note: Skipping reference inversion, as reference model has already been assigned')
#
# File ~/miniconda3/lib/python3.9/site-packages/resipy/Project.py:3216, in Project.write2protocol(self, err, errTot, fm0, **kwargs)
#    3212 # if not it means that the 'resError' columns has already
#    3213 # been populated when the files has been imported
#    3215 res0Bool = False if self.param['reg_mode'] == 1 else True
# -> 3216 protocol = s.write2protocol('', err=err, errTot=errTot, res0=res0Bool,
#    3217                             ip=False, # no IP timelapse possible for now
#    3218                             isubset=indexes[i], threed=threed,
#    3219                             fm0=fm0)
#    3220 if i == 0:
#    3221     refdir = os.path.join(self.dirname, 'ref')
#
# File ~/miniconda3/lib/python3.9/site-packages/resipy/Survey.py:2309, in Survey.write2protocol(self, outputname, err, errTot, ip, res0, isubset, threed, fm0)
#    2307     d0 = df['recipMean0'].values
#    2308     fm0 = fm0 # provided as already from quads in common
# -> 2309     protocol['res'] = d-d0+fm0 # according to R3t manual v3.2
#    2310 else:
#    2311     protocol['res'] = df['recipMean'].values # non-paired will be nan
#
# ValueError: operands could not be broadcast together with shapes (5453,) (5454,)

# %%
# save project
# -----------------------------------------------------------------------------
k.saveProject(dir_simu + 'Laghetti_June_TL' + 'regMode' + str(regMode))

# %% [markdown]
# # Results

# %%
k.showResults(attr='Resistivity(log10)', 
              sens=True, 
              contour=True, 
              use_pyvista=True,
              color_map='jet',zlim=[-30,0],
              background_color='white')

# %%
pl = pv.Plotter()
k.showResults(attr='Resistivity(ohm.m)',
              ax=pl, pvslices=([5,15,25],[15],[]), 
              pvgrid=True, 
              vmin=0, 
              vmax=300, 
              color_map='jet',zlim=[-30,0],
              background_color='white')

# %%
pl = pv.Plotter()
k.showResults(attr='Resistivity(ohm.m)',
              ax=pl, pvthreshold=[0,75], pvgrid=True,zlim=[-30,0],
              background_color='white')

# %%
k.showResults(index=1, pvslices=([],[],[-12]), 
              pvgrid=True, attr='difference(percent)', 
                contour=False, vmin=-25, vmax=0
             )

# %%
k.showResults(index=2,pvslices=([],[],[-12]), 
              pvgrid=True, attr='difference(percent)', 
                contour=False, vmin=-25, vmax=0
             )

# %%
k.showResults(index=3, 
    attr='difference(percent)', 
    contour=False, vmin=0, vmax=100)

# %%
k.showResults(index=4, 
    attr='difference(percent)', 
    contour=False, vmin=0, vmax=100)

# %%
k.showResults(index=5, 
    attr='difference(percent)', 
    contour=False, vmin=0, vmax=100)
